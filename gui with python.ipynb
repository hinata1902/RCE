# %%
import tkinter

root=tkinter.Tk() #creating window
root.geometry("500X500") #giving size
root.title("My App")
l=tkinter.Label(text="Enter Name")
l.place(x=50,y=60) #x and y coordinates
l.grid(row=0,column=0)
l.pack(side="right")
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[96], line 4
#       1 import tkinter
#       3 root=tkinter.Tk() #creating window
# ----> 4 root.geometry("500X500") #giving size
#       5 root.title("My App")
#       6 l=tkinter.Label(text="Enter Name")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py:2100, in Wm.wm_geometry(self, newGeometry)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py?line=2096'>2097</a> def wm_geometry(self, newGeometry=None):
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py?line=2097'>2098</a>     """Set geometry to NEWGEOMETRY of the form =widthxheight+x+y. Return
# ...

# %%
import tkinter

root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
l=tkinter.Label(text="Enter Name")
l.place(x=50,y=60) #x and y coordinates
l.grid(row=0,column=0)
l.pack(side="right")
root.mainloop()

# %%
import tkinter

root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
l=tkinter.Label(text="Enter Name")
l.place(x=50,y=60) #x and y coordinates
l.grid(row=0,column=0)
l.pack(side="right")
root.mainloop()

# %%
import tkinter

root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
l.place(x=50,y=60) #x and y coordinates
l.grid(row=0,column=0)
l.pack(side="right")
root.mainloop()

# %%
import tkinter

root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
l.place(x=50,y=60) #x and y coordinates
l.grid(row=0,column=0)
l.pack(side="right")
root.mainloop()

# %%
import tkinter

root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
l.place(x=50,y=60) #x and y coordinates
l.place(x=150,y=60)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter

root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
l.place(x=50,y=60) #x and y coordinates
l.place(x=150,y=60)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter

root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter

root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter

root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
b=tkinter.Button(text="Click")
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=60)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter

root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
b=tkinter.Button(text="Click")
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
def demo():
    print("welcome")
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
#l.pack(side="right")
root.mainloop()
# Out:
# welcome

# %%
import tkinter
from tkinter import messagebox

def demo():
    messagebox.showinfo("result","welcome")
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
from tkinter import messagebox

def demo():
    data=e.get()
    messagebox.showinfo("result",data)
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
from tkinter import messagebox

def demo():
    data=e.get()
    messagebox.showinfo("result",data)
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
from tkinter import messagebox

def demo():
    data=e.get()
    messagebox.showinfo("result",data)
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
from tkinter import messagebox

def demo():
    data=e.get()
    messagebox.showinfo("result",data)
    e.delete(0,'end')
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
from tkinter import messagebox

def demo():
    data=e.get()
    l2.config(text=data)
    e.delete(0,'end')
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l2=tkinter.Label()
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
l2.place(x=150,y=150)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
from tkinter import messagebox
from tkinter import ttk

def demo():
    data=e.get()
    l2.config(text=data)
    e.delete(0,'end')
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l2=tkinter.Label()
combo=tkinter.Combobox(root,values=["optional","option2","option3"])
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
l2.place(x=150,y=150)
#l.pack(side="right")
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[115], line 17
#      15 b=tkinter.Button(text="Click",command=demo)
#      16 l2=tkinter.Label()
# ---> 17 combo=tkinter.Combobox(root,values=["optional","option2","option3"])
#      18 l.place(x=50,y=60) #x and y coordinates
#      19 e.place(x=150,y=60)
#
# AttributeError: module 'tkinter' has no attribute 'Combobox'

# %%
import tkinter
from tkinter import messagebox
from tkinter import ttk

def demo():
    data=e.get()
    l2.config(text=data)
    e.delete(0,'end')
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l2=tkinter.Label()
combo=tkinter.Combobox(root,values=["optional","option2","option3"])
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
l2.place(x=150,y=150)
#l.pack(side="right")
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[116], line 17
#      15 b=tkinter.Button(text="Click",command=demo)
#      16 l2=tkinter.Label()
# ---> 17 combo=tkinter.Combobox(root,values=["optional","option2","option3"])
#      18 l.place(x=50,y=60) #x and y coordinates
#      19 e.place(x=150,y=60)
#
# AttributeError: module 'tkinter' has no attribute 'Combobox'

# %%
import tkinter
from tkinter import messagebox
from tkinter import ttk

def demo():
    data=e.get()
    l2.config(text=data)
    e.delete(0,'end')
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l2=tkinter.Label()
combo=ttk.Combobox(root,values=["optional","option2","option3"])
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
l2.place(x=150,y=150)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
from tkinter import messagebox
from tkinter import ttk

def demo():
    data=e.get()
    l2.config(text=data)
    e.delete(0,'end')
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l2=tkinter.Label()
combo=ttk.Combobox(root,values=["optional","option2","option3"])
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
l2.place(x=150,y=150)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
from tkinter import messagebox
from tkinter import ttk

def demo():
    data=e.get()
    l2.config(text=data)
    e.delete(0,'end')
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l2=tkinter.Label()
combo=ttk.Combobox(root,values=["optional","option2","option3"])
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
l2.place(x=150,y=150)
combo.place(x=150,y=200)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
from tkinter import messagebox
from tkinter import ttk

def demo():
    data=e.get()
    l2.config(text=data)
    e.delete(0,'end')
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l2=tkinter.Label()
combo=ttk.Combobox(root,values=["option1","option2","option3"])
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
l2.place(x=150,y=150)
combo.place(x=150,y=200)
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
from tkinter import messagebox
from tkinter import ttk

def demo():
    '''data=e.get()
    l2.config(text=data)
    e.delete(0,'end')'''
    data=combo.get()
    print(data)
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l2=tkinter.Label()
combo=ttk.Combobox(root,values=["option1","option2","option3"])
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
l2.place(x=150,y=150)
combo.place(x=150,y=200)
#l.pack(side="right")
root.mainloop()
# Out:
# option2
# option2

# %%
import tkinter
from tkinter import messagebox

def demo():
    data=e.get()
    messagebox.showinfo("result",data)
    e.delete(0,'end')
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
#l.pack(side="right")
root.mainloop()

# %%
import tkinter
from tkinter import messagebox

def demo():
    data=e.get()
    messagebox.showinfo("result",data)
    e.delete(0,'end')
root=tkinter.Tk() #creating window
root.geometry("500x500") #giving size
root.title("My App")
root.configure(background="yellow")
l=tkinter.Label(text="Enter Name",font=('Arial',10),foreground="blue",background="brown")
e=tkinter.Entry()
b=tkinter.Button(text="Click",command=demo)
l.place(x=50,y=60) #x and y coordinates
e.place(x=150,y=60)
b.place(x=150,y=100)
e.configure(background="red")
#l.pack(side="right")
root.mainloop()
